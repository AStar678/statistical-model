# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("../crop_yield.csv")

# %%
data.head(3)
# Out:
#   Region Soil_Type    Crop  Rainfall_mm  Temperature_Celsius  Fertilizer_Used  \
# 0   West     Sandy  Cotton   897.077239            27.676966            False
# 1  South      Clay    Rice   992.673282            18.026142             True
# 2  North      Loam  Barley   147.998025            29.794042            False
#
#    Irrigation_Used Weather_Condition  Days_to_Harvest  Yield_tons_per_hectare
# 0             True            Cloudy              122                6.555816
# 1             True             Rainy              140                8.527341
# 2            False             Sunny              106                1.127443

# %%
x = data["Soil_Type"]

# %%
y = data.groupby(['Soil_Type','Crop'])['Yield_tons_per_hectare'].mean()

# %%
y
# Out:
# Soil_Type  Crop
# Chalky     Barley     4.649948
#            Cotton     4.663595
#            Maize      4.653498
#            Rice       4.640907
#            Soybean    4.657995
#            Wheat      4.651330
# Clay       Barley     4.651793
#            Cotton     4.645118
#            Maize      4.630174
#            Rice       4.646297
#            Soybean    4.651116
#            Wheat      4.644797
# Loam       Barley     4.643126
#            Cotton     4.633848
#            Maize      4.666891
#            Rice       4.651742
#            Soybean    4.639517
#            Wheat      4.671253
# Peaty      Barley     4.650058
#            Cotton     4.647561
#            Maize      4.635270
#            Rice       4.657866
#            Soybean    4.661625
#            Wheat      4.654183
# Sandy      Barley     4.658929
#            Cotton     4.652088
#            Maize      4.632811
#            Rice       4.654259
#            Soybean    4.656205
# ...

# %% [markdown]
# #### 不同土壤的产量差异不大

# %%
y = data.groupby(['Crop'])['Yield_tons_per_hectare'].mean()
y
# Out:
# Crop
# Barley     4.647412
# Cotton     4.650841
# Maize      4.641387
# Rice       4.650760
# Soybean    4.653712
# Wheat      4.652740
# Name: Yield_tons_per_hectare, dtype: float64

# %% [markdown]
# #### 不同作物之间产量差异也不大

# %%
pro_data = pd.read_csv("../处理后的农产品数据.csv")

# %%
import seaborn as sns
sns.palplot(sns.color_palette("bright",10))

# %%
pro_data.corr()["hectare"]
# Out:
# hectare                     1.000000
# Rainfall_mm                 0.753762
# Temperature_Celsius         0.083837
# Fertilizer_Used             0.435465
# Irrigation_Used             0.348518
# Soil_Type_Chalky            0.000729
# Soil_Type_Clay             -0.001100
# Soil_Type_Loam              0.000042
# Soil_Type_Peaty             0.000532
# Soil_Type_Sandy            -0.000083
# Soil_Type_Silt             -0.000120
# Crop_Barley                -0.000499
# Crop_Cotton                 0.000506
# Crop_Maize                 -0.002094
# Crop_Rice                   0.000326
# Crop_Soybean                0.000983
# Crop_Wheat                  0.000779
# Weather_Condition_Cloudy   -0.001216
# Weather_Condition_Rainy     0.000109
# Weather_Condition_Sunny     0.001105
# Name: hectare, dtype: float64

# %%
from sklearn.utils import shuffle
pro_data = pd.read_csv("../crop_yield.csv")
pro_data = shuffle(pro_data).reset_index(drop=True)

pro_data = pro_data.iloc[:100]
plt.scatter(pro_data["Rainfall_mm"].values,pro_data["Yield_tons_per_hectare"].values)
plt.show()

# %%
sns.pairplot(pro_data)
plt.show()
